# %%
# Scipy:

# We have the min and max temperatures in a city In India for each months of the year.
# We would like to find a function to describe this and show it graphically, the dataset
# given below.

# Task:
# 1.fitting it to the periodic function
# 2.plot the fit

# Data
# Max = 39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25
# Min = 21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

from scipy.optimize import curve_fit
# %matplotlib inline

Max = [39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25]
Min = [21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18]
Month = np.arange(len(Max))

plt.figure(1)
plt.scatter(x = Month, y = Max, c = 'r')
plt.scatter(x = Month, y = Min, c = 'b')
plt.xlabel("Month")
plt.ylabel("Temperature (Celsius)")
plt.show()

def fit_func(t, w0, w1):
    return (w0 + w1 * np.cos(t * 2 * np.pi / t.max()))

p_opt_max, p_cov_max = curve_fit(fit_func, Month, Max, [20, 10])
p_opt_min, p_cov_min = curve_fit(fit_func, Month, Min, [-40, 20],)

days = np.linspace(0, 12, num=365)

plt.figure(2)
plt.plot(Month, Max, 'ro')
plt.plot(days, fit_func(days, *p_opt_max), 'r-')
plt.plot(Month, Min, 'bo')
plt.plot(days, fit_func(days, *p_opt_min), 'b-')
plt.xlabel('Month')
plt.ylabel("Temperature (Celsius)")

plt.show()

# %%
# Matplotlib:

# This assignment is for visualization using matplotlib:
# data to use:

# url=https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv

# titanic = pd.read_csv(url)

# Charts to plot:
# 1. Create a pie chart presenting the male/female proportion
# 2. Create a scatterplot with the Fare paid and the Age, differ the plot color by gender

df = pd.read_csv('https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv')


# 1. Create a pie chart presenting the male/female proportion
df['sex'].value_counts().plot.pie(figsize=(6,6), autopct='%1.0f%%')


# 2. Create a scatterplot with the Fare paid and the Age, differ the plot color by gender
plt.figure(2,figsize=(12,8))
sns.scatterplot(x='fare', y='age', data=df, hue='sex')
